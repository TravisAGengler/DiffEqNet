# %% [markdown]
# # Testing DiffEqNet models
# ## All models from https://github.com/khannay/FittingParamsDiffEqFlux

# %%
include("lotka_voltera.jl")

lotka_voltera.InitPlot()
resL=lotka_voltera.train_model()
lotka_voltera.plotFit(resL.minimizer)
lotka_voltera.validationPlot(resL.minimizer, [6.,6.])
# Out:
# The initial loss function is 1249.2543737953215
# loss: 2.33: 100%|█████████████████████████████████████████| Time: 0:00:34
# The parameters are [1.0097480275834516, 0.9855609762227171, 1.4887157913019484, 1.0024541197896981, 3.025671649418431, 1.005454353049186] with final loss value 2.136269201336802

# %%
include("kuramoto.jl")

kuramoto_model.InitPlot()
results_kuramoto=kuramoto_model.train_model()
kuramoto_model.plotFit(results_kuramoto.minimizer)
kuramoto_model.validationPlot(results_kuramoto.minimizer, π*rand(kuramoto_model.N))
kuramoto_model.validationPlot(results_kuramoto.minimizer, 1.5*π*rand(kuramoto_model.N))
# Out:
# The initial loss function is 334.4816631532576
# ┌ Warning: Interrupted. Larger maxiters is needed.
# └ @ DiffEqBase /home/tgengler/.julia/packages/DiffEqBase/wBR51/src/integrator_interface.jl:329
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase /home/tgengler/.julia/packages/DiffEqBase/wBR51/src/integrator_interface.jl:349
# ┌ Warning: Interrupted. Larger maxiters is needed.
# └ @ DiffEqBase /home/tgengler/.julia/packages/DiffEqBase/wBR51/src/integrator_interface.jl:329
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase /home/tgengler/.julia/packages/DiffEqBase/wBR51/src/integrator_interface.jl:349
# The parameters are [7.57796849336664, 0.12062463511933467, 1.7422469108753007, -0.9387078765817801] with final loss value 53.57192597560582

# %%
include("lorentz.jl")

lorenz_model.InitPlot()
resL=lorenz_model.train_model()
lorenz_model.plotFit(resL.minimizer; vars=(1,2,3), tend=30.0)
lorenz_model.plotFit(resL.minimizer; vars=(0,1), tend=30.0)
# Out:
# The initial loss function is 10618.042707784587
# loss: 1.74: 100%|█████████████████████████████████████████| Time: 0:01:53
# The parameters are [1.0039894883677294, -0.006742127513677775, -1.1509288141625863e-5, 9.999471297174857, 28.001223823791328, 2.666452582074018] with final loss value 1.6606547677966021

# %%
include("stuart_landau.jl")

sl_model.InitPlot()
res=sl_model.train_model()
sl_model.plotFit(res.minimizer)
sl_model.validationPlot(res.minimizer, [π, 0.6])
# Out:
# The initial loss function is 682.0069063313206
# loss: 1.31: 100%|█████████████████████████████████████████| Time: 0:00:32
# The parameters are [0.007504471107022092, 0.0769505695376358, 0.10333265978829531, 6.263109643099141, 0.12089239887121327, 1.025136791260371] with final loss value 0.8187723833689918
