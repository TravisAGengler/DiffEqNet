# %% [markdown]
# # Drosophila protein regulation model

# %%
include("drosophila_regulation.jl")

# These define the initial conditions of each of the runs
u0_1 = [0.2, 0.5]
u0_2 = [0.6, 0.3] 

drosophila_regulation.train_bistable_model_with_params([u0_1, u0_2])
# Out:
# Learning bistable parameters
# Initial loss: 64.45555655334071
# WARNING: replacing module drosophila_regulation.
# loss: 0.823: 100%|█████████████████████████████████████████| Time: 0:03:40
# Finished training after 1498 iterations
# Learned params
# p1: 0.2
# p2: 0.5
# α1_true / α1: 0.29 / 0.7627029352151089
# α2_true / α2: 0.19 / 0.5625649239123911
# β1_true / β1: 0.29 / 0.27796949968529233
# β2_true / β2: 0.19 / 0.29719249764048533
# k1_true / k1: 0.11 / 0.0760328366041783
# k2_true / k2: 0.08 / 0.22932706532265698
# n1_true / n1: 2.0 / 0.869135122587077
# n2_true / n2: 2.0 / 1.9884967084884323e-5
# φ11_true / φ11: 315.0 / 225.99426796574906
# φ12_true / φ12: 135.0 / 172.60914607433628
# φ21_true / φ21: 135.0 / 495.94253095356834
# φ22_true / φ22: 315.0 / 122.98966460524055
# Learned loss: 0.8221484460903994
# Initial loss: 49.71004957668822
# loss: 1.19: 100%|█████████████████████████████████████████| Time: 0:00:32
# Finished training after 225 iterations
# Learned params
# p1: 0.6
# p2: 0.3
# α1_true / α1: 0.29 / 0.792724998577241
# α2_true / α2: 0.19 / 0.47204838466511384
# β1_true / β1: 0.29 / 0.2509957736059971
# β2_true / β2: 0.19 / 0.4605930308444195
# k1_true / k1: 0.11 / 0.5711292861672603
# k2_true / k2: 0.08 / 0.22853493471791442
# n1_true / n1: 2.0 / 0.8339219334058912
# n2_true / n2: 2.0 / 0.3746660705558202
# φ11_true / φ11: 315.0 / 202.18367199084997
# φ12_true / φ12: 135.0 / 158.80525203046335
# φ21_true / φ21: 135.0 / 337.49630786851975
# φ22_true / φ22: 315.0 / 158.54146530750438
# Learned loss: 1.1939822100214992

# %%
# These define the initial conditions of each of the runs
u0_1 = [0.5, 0.5]
u0_2 = [0.4, 0.6] 

drosophila_regulation.train_mutual_inhib_model_with_params([u0_1, u0_2])
# Out:
# Initial loss: 967.9162122085127
# loss: 2.63: 100%|█████████████████████████████████████████| Time: 0:02:04
# Finished training after 872 iterations
# Learned params
# p1: 0.5
# p2: 0.5
# α1_true / α1: 0.29 / 0.6246723345189876
# α2_true / α2: 0.19 / 0.4543527383491358
# β1_true / β1: 0.26 / 0.20226367272028026
# β2_true / β2: 0.19 / 0.674736408225212
# k1_true / k1: 0.11 / 0.08378879240457247
# k2_true / k2: 0.12 / 0.29269877077141465
# n1_true / n1: 2.0 / 0.0073377238225384705
# n2_true / n2: 2.0 / 0.9487587182247944
# φ11_true / φ11: 45.0 / 270.3056175374737
# φ12_true / φ12: 135.0 / 286.99309335581876
# φ21_true / φ21: 135.0 / 313.15537857354866
# φ22_true / φ22: 45.0 / 351.049997586715
# Learned loss: 2.629098185255031
# Initial loss: 1035.2641197631049
# loss: 1.43: 100%|█████████████████████████████████████████| Time: 0:02:18
# Finished training after 983 iterations
# Learned params
# p1: 0.4
# p2: 0.6
# α1_true / α1: 0.29 / 0.6141083750682667
# α2_true / α2: 0.19 / 0.47721748239440104
# β1_true / β1: 0.26 / 0.21354768917940511
# β2_true / β2: 0.19 / 0.6569664606247828
# k1_true / k1: 0.11 / 0.0852213490355097
# k2_true / k2: 0.12 / 0.30138493193783955
# n1_true / n1: 2.0 / 0.0017542107291289005
# n2_true / n2: 2.0 / 0.9147516344158783
# φ11_true / φ11: 45.0 / 262.964228900539
# φ12_true / φ12: 135.0 / 281.7284032823656
# φ21_true / φ21: 135.0 / 320.5303065626884
# φ22_true / φ22: 45.0 / 357.306798841364
# Learned loss: 1.431293436792842
