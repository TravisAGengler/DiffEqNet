# %% [markdown]
# # Drosophila protein regulation model

# %%
include("drosophila_regulation.jl")

# These are the parameters that we are going to start with.
# Using ML, we hope to converge on the true_params
#                       p1,  p2,  α1,   α2,   β1,   β2,   k1,   k2,   n1,  n2,  φ11,   φ12,   φ21,   φ22
starting_u0_params_1 = [0.5, 0.5, 0.27, 0.20, 0.31, 0.17, 0.10, 0.10, 1.9, 2.1, 307.0, 136.0, 135.7, 312.0]

drosophila_regulation.train_models_with_params([starting_u0_params_1])
# Out:
# WARNING: replacing module drosophila_regulation.
# loss: 0.516: 100%|█████████████████████████████████████████| Time: 0:00:53
# loss: 0.403: 100%|█████████████████████████████████████████| Time: 0:00:44
# Learning bistable parameters
# Starting training run with:
# True params [0.5, 0.5, 0.29, 0.19, 0.29, 0.19, 0.11, 0.08, 2.0, 2.0, 315.0, 135.0, 135.0, 315.0]
# Initial params [0.5, 0.5, 0.27, 0.2, 0.31, 0.17, 0.1, 0.1, 1.9, 2.1, 307.0, 136.0, 135.7, 312.0]
# The initial loss is 0.6451384481274636
# The learned parameters are [0.5307357848320149, 0.4839734612860818, 0.043988717263048815, 20.074923496085457, 0.3333535096382186, 4.483781825347935, 1.7729281310986824, 1.2909707969684314, 0.10699451477320804, 2.0739622880087687, 305.29400324293175, 133.73460795746473, 127.01808185819947, 321.55754531427266] with final loss of 0.5076513589688466
# Learning mutual inhibition parameters
# Starting training run with:
# ...
