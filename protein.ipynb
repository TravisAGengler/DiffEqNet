# %% [markdown]
# # Drosophila protein regulation model

# %%
include("drosophila_regulation.jl")

# These define the initial conditions of each of the runs
u0_1 = [0.2, 0.5]
u0_2 = [0.6, 0.3] 

drosophila_regulation.train_bistable_model_with_params([u0_1, u0_2])
# Out:
# Learning bistable parameters
# WARNING: replacing module drosophila_regulation.
# Initial loss: 29.544240532774594
# loss: 1.08: 100%|█████████████████████████████████████████| Time: 0:00:20
# Finished training after 450 iterations
# Learned params
# p1: 0.2
# p2: 0.5
# α1_true / α1: 0.29 / 0.7906206445321271
# α2_true / α2: 0.19 / 0.44346020745901543
# β1_true / β1: 0.29 / 1.050207226802129
# β2_true / β2: 0.19 / 0.6178537192943717
# k1_true / k1: 0.11 / 0.009822558538811593
# k2_true / k2: 0.08 / 1.1340288071552342
# n1_true / n1: 2.0 / 0.5581627923524037
# n2_true / n2: 2.0 / 0.634326063422882
# φ11_true / φ11: 315.0 / 121.17214600810156
# φ12_true / φ12: 135.0 / 291.26573196080756
# φ21_true / φ21: 135.0 / 59.6700107897965
# φ22_true / φ22: 315.0 / 98.77029159657603
# Learned loss: 1.0749469875777633
# Initial loss: 5.6115081742232595
# loss: 0.421: 100%|█████████████████████████████████████████| Time: 0:00:06
# Finished training after 209 iterations
# Learned params
# p1: 0.6
# p2: 0.3
# α1_true / α1: 0.29 / 0.8537357916822057
# α2_true / α2: 0.19 / 0.2728390014063743
# β1_true / β1: 0.29 / 0.9827086124465123
# β2_true / β2: 0.19 / 0.8025918786640591
# k1_true / k1: 0.11 / 0.24112746485799835
# k2_true / k2: 0.08 / 1.0449018776070944
# n1_true / n1: 2.0 / 0.39546220391518966
# n2_true / n2: 2.0 / 0.5879278015949528
# φ11_true / φ11: 315.0 / 78.19057002751111
# φ12_true / φ12: 135.0 / 317.0330068263641
# φ21_true / φ21: 135.0 / 45.86833995315409
# φ22_true / φ22: 315.0 / 154.8790697290314
# Learned loss: 0.4203935945418205

# %%
# These define the initial conditions of each of the runs
u0_1 = [0.5, 0.5]
u0_2 = [0.4, 0.6] 

drosophila_regulation.train_mutual_inhib_model_with_params([u0_1, u0_2])
# Out:
# Initial loss: 3.4912674778053345
# loss: 0.173: 100%|█████████████████████████████████████████| Time: 0:00:05
# Finished training after 190 iterations
# Learned params
# p1: 0.5
# p2: 0.5
# α1_true / α1: 0.29 / 1.0111334259465987
# α2_true / α2: 0.19 / 0.7323017825925394
# β1_true / β1: 0.26 / 0.5455795423664911
# β2_true / β2: 0.19 / 0.28013552244431866
# k1_true / k1: 0.11 / 0.12827385995746216
# k2_true / k2: 0.12 / 0.9217935687947301
# n1_true / n1: 2.0 / 0.8501936233276579
# n2_true / n2: 2.0 / 0.18010637356227896
# φ11_true / φ11: 45.0 / 162.09052987442374
# φ12_true / φ12: 135.0 / 371.04584557524794
# φ21_true / φ21: 135.0 / 116.39203825596307
# φ22_true / φ22: 45.0 / 184.94135909028486
# Learned loss: 0.17325619139066423
# Initial loss: 1.479602270697606
# loss: 0.24: 100%|█████████████████████████████████████████| Time: 0:00:05m
# Finished training after 166 iterations
# Learned params
# p1: 0.4
# p2: 0.6
# α1_true / α1: 0.29 / 0.9569346101281332
# α2_true / α2: 0.19 / 0.765949530084445
# β1_true / β1: 0.26 / 0.550750132872575
# β2_true / β2: 0.19 / 0.3291515181894574
# k1_true / k1: 0.11 / 0.11217703709335122
# k2_true / k2: 0.12 / 0.9497547872573666
# n1_true / n1: 2.0 / 0.8553699157826563
# n2_true / n2: 2.0 / 0.27705694679371495
# φ11_true / φ11: 45.0 / 169.3086778433184
# φ12_true / φ12: 135.0 / 351.87892431688726
# φ21_true / φ21: 135.0 / 109.57495847295846
# φ22_true / φ22: 45.0 / 176.05728075959527
# Learned loss: 0.2395307730163713
