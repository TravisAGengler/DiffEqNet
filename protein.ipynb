# %% [markdown]
# # Drosophila protein regulation model

# %%
include("drosophila_regulation.jl")

# These define the initial conditions of each of the runs
u0_1 = [0.2, 0.5]
u0_2 = [0.6, 0.3] 

drosophila_regulation.train_bistable_model_with_params([u0_1, u0_2])
# Out:
# Learning bistable parameters
# Initial loss: 103.76421463114076
# WARNING: replacing module drosophila_regulation.
# loss: 6.14:   3%|█▍                                       |  ETA: 0:15:29┌ Warning: dt <= dtmin. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ DiffEqBase /home/tgengler/.julia/packages/DiffEqBase/wBR51/src/integrator_interface.jl:343
# loss: 1.18: 100%|█████████████████████████████████████████| Time: 0:02:45
# Finished training after 1071 iterations
# Learned params
# p1: 0.2
# p2: 0.5
# α1_true / α1: 0.29 / 0.6564194109409597
# α2_true / α2: 0.19 / 0.6852538589609769
# β1_true / β1: 0.29 / 0.5634557396981934
# β2_true / β2: 0.19 / 0.5743157591552946
# k1_true / k1: 0.11 / 0.09309341549355958
# k2_true / k2: 0.08 / 1.0390135736976343
# n1_true / n1: 2.0 / 0.5652639337829445
# n2_true / n2: 2.0 / 0.3956482530348316
# φ11_true / φ11: 315.0 / 269.8646726819027
# φ12_true / φ12: 135.0 / 168.62878014334729
# φ21_true / φ21: 135.0 / 142.73650132667663
# φ22_true / φ22: 315.0 / 77.01401191704333
# Learned loss: 1.1811715917133756
# Initial loss: 8.559101020445794
# loss: 1.07: 100%|█████████████████████████████████████████| Time: 0:00:50
# Finished training after 373 iterations
# Learned params
# p1: 0.6
# p2: 0.3
# α1_true / α1: 0.29 / 0.7901439349634253
# α2_true / α2: 0.19 / 0.5532122415896827
# β1_true / β1: 0.29 / 0.4149918191803908
# β2_true / β2: 0.19 / 0.6717969085558786
# k1_true / k1: 0.11 / 0.2273177670439041
# k2_true / k2: 0.08 / 0.9242652951679641
# n1_true / n1: 2.0 / 0.26227909761105556
# n2_true / n2: 2.0 / 0.3662057965406715
# φ11_true / φ11: 315.0 / 262.18564301509787
# φ12_true / φ12: 135.0 / 111.18439390448874
# φ21_true / φ21: 135.0 / 156.6429763489053
# φ22_true / φ22: 315.0 / 124.98122306083808
# Learned loss: 1.0678292844803132

# %%
# These define the initial conditions of each of the runs
u0_1 = [0.5, 0.5]
u0_2 = [0.4, 0.6] 

drosophila_regulation.train_mutual_inhib_model_with_params([u0_1, u0_2])
# Out:
# Initial loss: 548.3596884513562
# loss: 1.21: 100%|█████████████████████████████████████████| Time: 0:00:48
# Finished training after 341 iterations
# Learned params
# p1: 0.5
# p2: 0.5
# α1_true / α1: 0.29 / 0.7361644260585148
# α2_true / α2: 0.19 / 0.5345951267906088
# β1_true / β1: 0.26 / 0.7330185161465077
# β2_true / β2: 0.19 / 0.3857830600774869
# k1_true / k1: 0.11 / 0.5159992433332035
# k2_true / k2: 0.12 / 1.0435470181278679
# n1_true / n1: 2.0 / 0.4441026507755685
# n2_true / n2: 2.0 / 0.5066972536158251
# φ11_true / φ11: 45.0 / 379.7296999260868
# φ12_true / φ12: 135.0 / 304.08425150779635
# φ21_true / φ21: 135.0 / 28.55924045008414
# φ22_true / φ22: 45.0 / 293.1714012224902
# Learned loss: 1.2146274569262498
# Initial loss: 444.1710388484206
# loss: 1.67: 100%|█████████████████████████████████████████| Time: 0:00:42
# Finished training after 311 iterations
# Learned params
# p1: 0.4
# p2: 0.6
# α1_true / α1: 0.29 / 0.7147080066202365
# α2_true / α2: 0.19 / 0.5403920342640081
# β1_true / β1: 0.26 / 0.7468941194649314
# β2_true / β2: 0.19 / 0.37997970847513324
# k1_true / k1: 0.11 / 0.5082052979304946
# k2_true / k2: 0.12 / 1.0347780250829128
# n1_true / n1: 2.0 / 0.4425619524742526
# n2_true / n2: 2.0 / 0.4927027917196266
# φ11_true / φ11: 45.0 / 369.4487375578478
# φ12_true / φ12: 135.0 / 293.5578027696553
# φ21_true / φ21: 135.0 / 30.928367870680336
# φ22_true / φ22: 45.0 / 296.8732483053778
# Learned loss: 1.6690985900431659
