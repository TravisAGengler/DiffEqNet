# %% [markdown]
# # Drosophila protein regulation model

# %%
include("drosophila_regulation.jl")

# These are the parameters that we are going to start with.
# Using ML, we hope to converge on the true_params
# The angle parameters are normalized between 0 and 1
starting_u0_params1 = 
   [0.2,            # p1
    0.5,            # p2
    0.27,           # α1
    0.20,           # α2
    0.31,           # β1
    0.17,           # β2
    0.10,           # k1
    0.10,           # k2
    1.9,            # n1
    2.1,            # n2
    307.0 / 360.0,  # φ11
    136.0 / 360.0,  # φ12
    135.7 / 360.0,  # φ21
    312.0 / 360.0]  # φ22

starting_u0_params2 = 
   [0.6,            # p1
    0.3,            # p2
    0.27,           # α1
    0.20,           # α2
    0.31,           # β1
    0.17,           # β2
    0.10,           # k1
    0.10,           # k2
    1.9,            # n1
    2.1,            # n2
    307.0 / 360.0,  # φ11
    136.0 / 360.0,  # φ12
    135.7 / 360.0,  # φ21
    312.0 / 360.0]  # φ22

drosophila_regulation.train_bistable_model_with_params([starting_u0_params1, starting_u0_params2])
# Out:
# Learning bistable parameters
# Starting training run with:
# True params [0.2, 0.5, 0.29, 0.19, 0.29, 0.19, 0.11, 0.08, 2.0, 2.0, 0.875, 0.375, 0.375, 0.875]
# Initial params [0.2, 0.5, 0.27, 0.2, 0.31, 0.17, 0.1, 0.1, 1.9, 2.1, 0.8527777777777777, 0.37777777777777777, 0.3769444444444444, 0.8666666666666667]
# WARNING: replacing module drosophila_regulation.
# The initial loss is 0.5983271956517504
# loss: 0.419: 100%|█████████████████████████████████████████| Time: 0:00:16
# The learned parameters are [0.1881640313961709, 0.5159861406784493, 0.25033039853048156, 0.20796603708171704, 0.3066325419589722, 0.18168779767177853, 0.10511263118217186, 0.07673954758170576, 1.9904131134442404, 2.115685118103927, 0.9701374949980854, 0.36325956686752553, 0.383948190295108, 0.8748013713903661] with final loss of 0.4186095934575216
# Learning bistable parameters
# Starting training run with:
# True params [0.6, 0.3, 0.29, 0.19, 0.29, 0.19, 0.11, 0.08, 2.0, 2.0, 0.875, 0.375, 0.375, 0.875]
# ...

# %%
# These are the parameters that we are going to start with.
# Using ML, we hope to converge on the true_params
# The angle parameters are normalized between 0 and 1
starting_u0_params1 = 
   [0.5,            # p1
    0.5,            # p2
    0.25,           # α1
    0.22,           # α2
    0.23,           # β1
    0.22,           # β2
    0.15,           # k1
    0.16,           # k2
    2.3,            # n1
    1.5,            # n2
    70.0  / 360.0,  # φ11
    150.0 / 360.0,  # φ12
    120.0 / 360.0,  # φ21
    30.8  / 360.0]  # φ22

starting_u0_params2 = 
   [0.4,            # p1
    0.6,            # p2
    0.25,           # α1
    0.22,           # α2
    0.23,           # β1
    0.22,           # β2
    0.15,           # k1
    0.16,           # k2
    2.3,            # n1
    1.5,            # n2
    70.0  / 360.0,  # φ11
    150.0 / 360.0,  # φ12
    120.0 / 360.0,  # φ21
    30.8  / 360.0]  # φ22

drosophila_regulation.train_mutual_inhib_model_with_params([starting_u0_params1, starting_u0_params2])
# Out:
# Learning mutual inhibition parameters
# Starting training run with:
# True params [0.5, 0.5, 0.29, 0.19, 0.26, 0.19, 0.11, 0.12, 2.0, 2.0, 0.125, 0.375, 0.375, 0.125]
# Initial params [0.5, 0.5, 0.25, 0.22, 0.23, 0.22, 0.15, 0.16, 2.3, 1.5, 0.19444444444444445, 0.4166666666666667, 0.3333333333333333, 0.08555555555555555]
# The initial loss is 4.908765732049176
# loss: 0.485: 100%|█████████████████████████████████████████| Time: 0:00:09
# The learned parameters are [0.4956815212394654, 0.5160560970807705, 0.25915327707848274, 0.19418051526742677, 0.24081827021307717, 0.23349058224935884, 0.11690025776508738, 0.16495026571908677, 2.330755490959989, 1.5010777721261868, 0.1934850549439531, 0.41544438525607, 0.3544897659225004, 0.10106335887895021] with final loss of 0.48457525222157516
# Learning mutual inhibition parameters
# Starting training run with:
# True params [0.4, 0.6, 0.29, 0.19, 0.26, 0.19, 0.11, 0.12, 2.0, 2.0, 0.125, 0.375, 0.375, 0.125]
# ...
