# %% [markdown]
# # Testing training with multiple initial conditions and parameters

# %%
include("lotka_voltera_multirun.jl")

# These are the parameters that we are going to start with.
# Using ML, we hope to converge on the true_params
# These are x0, y0, α, β, δ, γ respectively
starting_u0_params_1 = [1.0, 1.0, 1.2, 1.0, 2.9, 1.1]
starting_u0_params_2 = [2.0, 3.0, 0.8, 1.1, 3.1, 0.9]

lotka_voltera_multirun.train_models_with_params([starting_u0_params_1, starting_u0_params_2])
# Out:
# Starting training run with:
# True params [1.0, 1.0, 1.5, 1.0, 3.0, 1.0]
# Initial params [1.0, 1.0, 1.2, 1.0, 2.9, 1.1]
# The initial loss is 831.9943628295702
# loss: 2.58: 100%|█████████████████████████████████████████| Time: 0:01:17
# The learned parameters are [1.0013500973251492, 1.0052365688016913, 1.5035444838876304, 1.000830519695568, 2.9901170352998463, 0.9951101551177738] with final loss of 1.982377591352213
# Starting training run with:
# True params [2.0, 3.0, 1.5, 1.0, 3.0, 1.0]
# Initial params [2.0, 3.0, 0.8, 1.1, 3.1, 0.9]
# The initial loss is 1111.9600219177685
# loss: 294: 100%|█████████████████████████████████████████| Time: 0:00:19
# The learned parameters are [2.1157230522220027, 1.3217022573986528, 1.4099357285686092, 0.9184328919787966, 0.8263083547402348, 0.2998007430375984] with final loss of 282.5398390888664
